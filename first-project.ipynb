# %%
from statsmodels.regression.rolling import RollingOLS
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import pandas_ta
import warnings
warnings.filterwarnings('ignore')

sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

sp500['Symbol'] = sp500['Symbol'].str.replace('.','-')

symbols_list = sp500['Symbol'].unique().tolist()

# Because this is the most up to date version of the SP500 companies
# our model will contain Survivorship Bias.

end_date = '2024-09-23'
start_date = pd.to_datetime(end_date)-pd.DateOffset(365 * 8)

start_date

df = yf.download(tickers=symbols_list,
                 start=start_date,
                 end=end_date)
# Out:
# Timestamp('2016-09-25 00:00:00')

# %%
msft = yf.Ticker('MSFT')
msft.news
# Out:
# [{'uuid': '027b24d8-b106-3549-b56e-20d05ed7a967',
#   'title': 'OpenAI Discusses Giving Altman 7% Stake in For-Profit Shift',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/openai-cto-mira-murati-says-194450279.html',
#   'providerPublishTime': 1727366159,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/v9EZcL3qg2wf_7jPqVwKGg--~B/aD0xMzMzO3c9MjAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bloomberg_technology_68/3ff5b7561044112816b40b003b05af5c',
#      'width': 2000,
#      'height': 1333,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/tDJ_N8R2wQT1UllmIIgw0Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_technology_68/3ff5b7561044112816b40b003b05af5c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'MSFT']},
#  {'uuid': '128b47ac-d677-39a0-bcae-af3cadc5e9bb',
#   'title': "Microsoft's Nuclear Deal Signals A Trend Change; S&P 500 Utility Stocks Look To Rally",
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/128b47ac-d677-39a0-bcae-af3cadc5e9bb/microsoft%27s-nuclear-deal.html',
#   'providerPublishTime': 1727364309,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/PpDQTjRhb0SBjdFnvrcwOw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/7b76d405170c8732e2685ea7a68fdd0a',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/l_rRiie7pefc0hjpcoQPgQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/7b76d405170c8732e2685ea7a68fdd0a',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC', 'MSFT', 'FLS', 'NRG', 'VST']},
#  {'uuid': '38f0fc0a-187c-3fa7-bc20-b98d2fda876c',
#   'title': 'Microsoft to make $2.7 billion cloud, AI investments in Brazil',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/microsoft-2-7-billion-cloud-151955412.html',
#   'providerPublishTime': 1727363995,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/J3EcgwokofFbJk0Y_Gze8w--~B/aD01MzY7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/f9ce68531038dd136c53e26cdd6dbc98',
#      'width': 800,
#      'height': 536,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/XsrUZSWQ7WAogJK_3Iwtvw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/f9ce68531038dd136c53e26cdd6dbc98',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '292aca14-3f85-3942-96f6-606e713f2cac',
#   'title': 'Microsoft Azure Sales Estimate Lowered As Copilots Slow To Take Off',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/292aca14-3f85-3942-96f6-606e713f2cac/microsoft-azure-sales.html',
#   'providerPublishTime': 1727362947,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/2heGKce7ZK.cnnWkO09slw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/84a8a3d542734ae48cf47f17744cb02c',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/UJdMyVqEeTOAewF_l2Qgvw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/84a8a3d542734ae48cf47f17744cb02c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b',
#   'title': 'Magnificent Seven Stocks: Nvidia Stock Continues To Rally; Tesla Threatens Win Streak',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks%3A.html',
#   'providerPublishTime': 1727361822,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/9_8WjQ09vg1Jxjxix3Jk_g--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/49620d487cd7222bded9f672f0ff985c',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/IHg8rTUpA9OasgazHA_oqg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/49620d487cd7222bded9f672f0ff985c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'AAPL', 'TSLA', 'META', 'MSFT']},
#  {'uuid': 'c9c163ad-8730-46e2-8a6e-17d805e268cc',
#   'title': 'Meta stock hits all-time high as Wall Street bets on AI vision',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/meta-stock-hits-all-time-high-as-wall-street-bets-on-ai-vision-142944019.html',
#   'providerPublishTime': 1727360984,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/_HRNNZTviL7r6o77Msv2Vg--~B/aD0zMjYxO3c9NDg5MjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-09/c28bcbf0-7c0f-11ef-87fd-e105fe32ea3e',
#      'width': 4892,
#      'height': 3261,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/zDjny4pg35Mrdd8orL6uzg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2024-09/c28bcbf0-7c0f-11ef-87fd-e105fe32ea3e',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'MSFT', 'META']},
#  {'uuid': '659760fa-16b6-3ff3-b0fb-9a51b6bf1aec',
#   'title': 'OpenAI To Restructure Into For-Profit Company, Give Altman Stake, Reports Say',
#   'publisher': 'Investopedia',
#   'link': 'https://finance.yahoo.com/m/659760fa-16b6-3ff3-b0fb-9a51b6bf1aec/openai-to-restructure-into.html',
#   'providerPublishTime': 1727357842,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/c.aMNMqhRhUGOKiLuEhKag--~B/aD0xOTk3O3c9MzAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/investopedia_245/2952c691146210b619198d43c3137fda',
#      'width': 3000,
#      'height': 1997,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/zcXTNE13w0LlXNXZWR54zA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/investopedia_245/2952c691146210b619198d43c3137fda',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '91205946-76c9-4eb3-82a9-e67e74683ee8',
#   'title': "All eyes are on Meta's smart glasses, but questions persist over its secretive AR project",
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/all-eyes-are-on-metas-smart-glasses-but-questions-persist-over-its-secretive-ar-project-123202248.html',
#   'providerPublishTime': 1727353922,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/rCG6KD4dODjplPmh7DR.wQ--~B/aD00MDAwO3c9NjAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-09/7e1cc850-7b8f-11ef-aeff-965a50fe7fe4',
#      'width': 6000,
#      'height': 4000,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/zwyFTXDPiFbUBi.xDMUfcQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2024-09/7e1cc850-7b8f-11ef-aeff-965a50fe7fe4',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['SNAP', 'GOOG', 'MSFT', 'META']}]

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.6.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2024.8.30
# cffi                      1.17.1
# charset-normalizer        3.3.2
# clarabel                  0.9.0
# comm                      0.2.2
# contourpy                 1.3.0
# cvxpy                     1.5.3
# cycler                    0.12.1
# DateTime                  5.5
# debugpy                   1.8.6
# decorator                 5.1.1
# defusedxml                0.7.1
# ecos                      2.0.14
# executing                 2.1.0
# fastjsonschema            2.20.0
# fonttools                 4.54.1
# fqdn                      1.5.1
# frozendict                2.4.4
# h11                       0.14.0
# html5lib                  1.1
# httpcore                  1.0.5
# httpx                     0.27.2
# idna                      3.10
# ipykernel                 6.29.5
# ipython                   8.27.0
# ipywidgets                8.1.5
# isoduration               20.11.0
# jedi                      0.19.1
# Jinja2                    3.1.4
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# kiwisolver                1.4.7
# lxml                      5.3.0
# MarkupSafe                2.1.5
# matplotlib                3.9.2
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# multitasking              0.0.11
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.2.2
# notebook_shim             0.2.4
# numpy                     1.26.4
# osqp                      0.6.7.post1
# overrides                 7.7.0
# packaging                 24.1
# pandas                    2.2.3
# pandas-datareader         0.10.0
# pandas_ta                 0.3.14b0
# pandocfilters             1.5.1
# parso                     0.8.4
# patsy                     0.5.6
# peewee                    3.17.6
# pexpect                   4.9.0
# pillow                    10.4.0
# pip                       23.2.1
# platformdirs              4.3.6
# prometheus_client         0.21.0
# prompt_toolkit            3.0.48
# psutil                    6.0.0
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 2.22
# Pygments                  2.18.0
# pyparsing                 3.1.4
# pyportfolioopt            1.5.5
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pytz                      2024.2
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# qdldl                     0.1.7.post4
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.20.0
# scipy                     1.14.1
# scs                       3.2.7
# Send2Trash                1.8.3
# setuptools                65.5.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# statsmodels               0.14.3
# terminado                 0.18.1
# tinycss2                  1.3.0
# tornado                   6.4.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240906
# typing_extensions         4.12.2
# tzdata                    2024.2
# uri-template              1.3.0
# urllib3                   2.2.3
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# widgetsnbextension        4.0.13
# yfinance                  0.2.43
# zope.interface            7.0.3
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
